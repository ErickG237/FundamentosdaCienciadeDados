# %% [markdown]
# ## Dicionário

# %%
#Usado para quem trabalha com JavaScript (jay son)
meu_dicionario = {"nome":"Paulo", "idade": 30, "filhos": ['João', 'Maria']}

# %%
meu_dicionario
# Out:
# {'nome': 'Paulo', 'idade': 30, 'filhos': ['João', 'Maria']}

# %%
# Acessando elementos do dicionário
meu_dicionario['nome']
# Out:
# 'Paulo'

# %%
# Acrescentando elementos no dicionário
meu_dicionario['cidade'] = "Cariacica"

# %%
meu_dicionario
# Out:
# {'nome': 'Paulo',
#  'idade': 30,
#  'filhos': ['João', 'Maria'],
#  'cidade': 'Cariacica'}

# %%
meu_dicionario['País'] = "Brasil"

# %%
meu_dicionario
# Out:
# {'nome': 'Paulo',
#  'idade': 30,
#  'filhos': ['João', 'Maria'],
#  'cidade': 'Cariacica',
#  'País': 'Brasil'}

# %%
meu_dicionario['Profissão'] = "Narcotraficante"

# %%
meu_dicionario
# Out:
# {'nome': 'Paulo',
#  'idade': 30,
#  'filhos': ['João', 'Maria'],
#  'cidade': 'Cariacica',
#  'País': 'Brasil',
#  'Profissão': 'Narcotraficante'}

# %%
meu_dicionario['Frase'] = "Hoje está 'quente'"

# %%
#Acessando as chaves do dicionário
meu_dicionario.keys()
# Out:
# dict_keys(['nome', 'idade', 'filhos', 'cidade', 'País', 'Profissão', 'Frase'])

# %%
#Acesso aos itens do dicionário (em listas de tuplas)
meu_dicionario.items()
# Out:
# dict_items([('nome', 'Paulo'), ('idade', 30), ('filhos', ['João', 'Maria']), ('cidade', 'Cariacica'), ('País', 'Brasil'), ('Profissão', 'Narcotraficante'), ('Frase', "Hoje está 'quente'")])

# %%
meu_dicionario.values()
# Out:
# dict_values(['Paulo', 30, ['João', 'Maria'], 'Cariacica', 'Brasil', 'Narcotraficante', "Hoje está 'quente'"])

# %%
print("O nome do professor é", meu_dicionario['nome'])
# Out:
# O nome do professor é Paulo

# %%
print("A profissão dos meus sonhos é ", meu_dicionario['Profissão'])
# Out:
# A profissão dos meus sonhos é:  Narcotraficante

# %%
meu_dicionario_2 = {}
print("Digite o nome: ")
meu_dicionario_2['nome'] = input()
print("Digite a sua idade: ")
meu_dicionario_2['idade'] = float(input())
print("Digite a sua profissão: ")
meu_dicionario_2['profissão'] = input()
# Out:
# Digite o nome:
#  Matheus
# Digite a sua idade:
#  21
# Digite a sua profissão:
#  estagiário

# %%
meu_dicionario_2
# Out:
# {'nome': 'Matheus', 'idade': 21.0, 'profissão': 'estagiário'}

# %% [markdown]
# ## Tuplas

# %%
#Parecido com uma lista, usado para fazer atribuições múltiplas de variáveis
t = (1,2,3)

# %%
#Acessando elementos da tupla
t[1]
# Out:
# 2

# %%
#Atribuição dupla de variáveis
a, b = (1,2)
